# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import streamlit as st

# %%
#df= pd.read_csv("csv/top10temp.csv")
df["planet discovery method"].unique()
# Out:
# array(['Transit'], dtype=object)

# %%
df["planet type"].unique()
# Out:
# array(['Super Earth', 'Neptune-like', 'Terrestrial', 'Gas Giant'],
#       dtype=object)

# %%
df.columns
# Out:
# Index(['Unnamed: 0.1', 'Unnamed: 0', 'index', 'row', 'name',
#        'light years from earth', 'planet mass', 'stellar magnitude',
#        'discovery date_x', 'planet type', 'planet radius', 'orbital period',
#        'solar system name', 'planet discovery method', 'host temperature (Cº)',
#        'host mass', 'host radius', 'Tª type', 'distance type',
#        'planet radius [0]', 'indice masa', 'tipo tamaño', 'description',
#        'discovery date_y', 'kepid', 'koi_impact', 'koi_prad'],
#       dtype='object')

# %%
def tabla_velocidad(seleccion):
    tab1, tab2 ,tab3, tab4 = st.tabs(["andando", "bicicleta","coche","barco","avión","cohete"])
    res = (((df["light years from earth"][df["name"] == seleccion]))/0.306601)/(5 * 24)
    tab1.write("Tardarias {res} días en llegar")
    tab2.write(df["light years from earth"][df["name"] == seleccion])
    tab3.write(df["light years from earth"][df["name"] == seleccion])
    tab4.write(df["light years from earth"][df["name"] == seleccion])

# %%
df= pd.read_csv("csv/top10_temp.csv")
df
# Out:
#    Unnamed: 0.1  Unnamed: 0  index   row           name  \
# 0           773         773    774  2193  Kepler-1585 b
# 1           852         852    855  2274   Kepler-164 b
# 2           854         854    857  2276   Kepler-164 d
# 3           855         855    858  2277  Kepler-1650 b
# 4          1586        1586   1605  3024   Kepler-422 b
# 5          1587        1587   1606  3025   Kepler-423 b
# 6          1588        1588   1607  3026   Kepler-424 b
# 7          1622        1622   1643  3062   Kepler-445 d
# 8          1623        1623   1644  3063   Kepler-446 b
# 9          1624        1624   1645  3064   Kepler-446 c
#
#    light years from earth     planet mass  stellar magnitude  \
# 0                  4139.0     3.86 Earths             15.977
# 1                  2982.0     2.57 Earths             14.233
# 2                  2982.0     6.57 Earths             14.233
# 3                   393.0     0.84 Earths             15.739
# ...

# %%
df["planet type"][df["name"] == "Kepler-446 b"]
# Out:
# 8    Super Earth
# Name: planet type, dtype: object

# %%
df["host temperature (Cº)"]= df["host temperature (Cº)"].round()
df_1["host temperature (Cº)"]= df_1["host temperature (Cº)"].round()

# %%
#df_1= pd.read_csv("csv/top10tam.csv")
#df_1.drop("Unnamed: 0",axis=1, inplace=True)

# %%
df.drop(["planet radius", "orbital period","discovery date_y", "kepid","koi_prad"], axis = 1, inplace = True)
df_1.drop(["planet radius", "orbital period","discovery date_y", "kepid","koi_prad"], axis = 1, inplace = True)

# %%
df_1.to_csv("top10tam.csv")

# %%
crear_radar(df)
# Out:
# 2023-02-01 20:54:41.863 Fontsize 0.00 < 1.0 pt not allowed by FreeType. Setting fontsize = 1 pt
# 2023-02-01 20:54:41.867 Fontsize 0.00 < 1.0 pt not allowed by FreeType. Setting fontsize = 1 pt
# 2023-02-01 20:54:41.867 Fontsize 0.00 < 1.0 pt not allowed by FreeType. Setting fontsize = 1 pt
# 2023-02-01 20:54:41.869 Fontsize 0.00 < 1.0 pt not allowed by FreeType. Setting fontsize = 1 pt
# 2023-02-01 20:54:41.871 Fontsize 0.00 < 1.0 pt not allowed by FreeType. Setting fontsize = 1 pt
# 2023-02-01 20:54:41.872 Fontsize 0.00 < 1.0 pt not allowed by FreeType. Setting fontsize = 1 pt
# 2023-02-01 20:54:41.872 Fontsize 0.00 < 1.0 pt not allowed by FreeType. Setting fontsize = 1 pt
# 2023-02-01 20:54:41.875 Fontsize 0.00 < 1.0 pt not allowed by FreeType. Setting fontsize = 1 pt
# 2023-02-01 20:54:41.876 Fontsize 0.00 < 1.0 pt not allowed by FreeType. Setting fontsize = 1 pt

# %%
df= pd.read_csv("csv/top10temp.csv")

# %%
def crear_radar(df):
   
    df.drop(["name","discovery date_x", "solar system name","planet discovery method","description"], axis = 1)
    df_numeric = df.select_dtypes(include = np.number)

    labels = df_numeric.columns.tolist()
    
    
    # create a list with the average of all features
    value=df_numeric.mean().tolist()
    fig = plt.figure(figsize = (18,18))
    # repeat first value to close the circle
    # the plot is a circle, so we need to "complete the loop"
    # and append the start value to the end.
    value.append(value[0])
    
    N=len(labels)
    # calculate angle for each category
    angles=[n/float(N)*2*np.pi for n in range(N)]
    angles.append(angles[0])


    # plot
    plt.polar(angles, value, color = "black")
    plt.fill(angles,value,alpha=0.5, facecolor='#1DB954')

    # plt.title('Discovery Weekly Songs Audio Features', size=35)

    plt.xticks(angles[:-1],labels, size=15)
    plt.yticks(size = 0)
    plt.savefig("images/radar.jpg")

# %%
st.markdown("###### por temperatur")
df= pd.read_csv("csv/top10temp.csv")
lista = df["name"].to_list()
seleccion = st.selectbox('Pick one',lista)
seleccion
descripccion = df[df["name"] == seleccion]
st.write(descripccion["description"])
"""x = st.selectbox('Pick one', ["-",'Temperatura', 'Tamaño'])
sp.seleccion(x)"""

        
st.markdown("###### por tamaño")

# %%
def crear_radar(df,planeta):
   
    df.drop(["name","discovery date_x", "solar system name","planet discovery method","description"], axis = 1)
    df_numeric = df.select_dtypes(include = np.number)

    labels = df_numeric.columns.tolist()
    
    
    # create a list with the average of all features
    
    value=df_numeric[df_numeric["name"]== planeta].values.tolist()

    fig = plt.figure(figsize = (18,18))
    # repeat first value to close the circle
    # the plot is a circle, so we need to "complete the loop"
    # and append the start value to the end.
    value.append(value[0])
    
    N=len(labels)
    # calculate angle for each category
    angles=[n/float(N)*2*np.pi for n in range(N)]
    angles.append(angles[0])


    # plot
    plt.polar(angles, value, color = "black")
    plt.fill(angles,value,alpha=0.5, facecolor='#1DB954')

    # plt.title('Discovery Weekly Songs Audio Features', size=35)

    plt.xticks(angles[:-1],labels, size=15)
    plt.yticks(size = 0)
    plt.savefig("images/radar.jpg")

# %%
crear_radar(df,"Kepler-164 b")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\pedro\ironhack\clase\labs\lab-streamlit\notebook.ipynb Cell 25 in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/c%3A/Users/pedro/ironhack/clase/labs/lab-streamlit/notebook.ipynb#X36sZmlsZQ%3D%3D?line=0'>1</a> crear_radar(df,"Kepler-164 b")
#
# c:\Users\pedro\ironhack\clase\labs\lab-streamlit\notebook.ipynb Cell 25 in crear_radar(df, planeta)
#       <a href='vscode-notebook-cell:/c%3A/Users/pedro/ironhack/clase/labs/lab-streamlit/notebook.ipynb#X36sZmlsZQ%3D%3D?line=5'>6</a> labels = df_numeric.columns.tolist()
#       <a href='vscode-notebook-cell:/c%3A/Users/pedro/ironhack/clase/labs/lab-streamlit/notebook.ipynb#X36sZmlsZQ%3D%3D?line=8'>9</a> # create a list with the average of all features
# ...
